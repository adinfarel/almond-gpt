# %% [markdown]
# # AlmondGPT

# %% [markdown]
# #### Importing the libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import json
import os

# %% [markdown]
# #### Loaded the dataset

# %%
# loaded the dataset
path_file = r'../data/raw/input.txt'
try:
    with open(path_file, 'r', encoding='utf-8') as f:
        text = f.read()
        print('Dataset was succesfully loaded!!!')
except Exception as e:
    raise FileNotFoundError(f'This path:{path_file} not found in directory')
# Out:
# Dataset was succesfully loaded!!!

# %% [markdown]
# #### Overview

# %%
# dataset info
print(f"Length of dataset: {len(text)}")
print(f"Preview dataset:\n{text[:1000]}")
# Out:
# Length of dataset: 6701920
# Preview dataset:
# User: When did Virgin Australia start operating?
# Almond: Virgin Australia commenced services on 31 August 2000 as Virgin Blue, with two aircraft on a single route.
#
# User: Which is a species of fish? Tope or Rope
# Almond: Tope
#
# User: Why can camels survive for long without water?
# Almond: Camels use the fat in their humps to keep them filled with energy and hydration for long periods of time.
#
# User: Alice's parents have three daughters: Amy, Jessy, and what’s the name of the third daughter?
# Almond: The name of the third daughter is Alice
#
# User: When was Tomoaki Komorida born?
# Almond: Tomoaki Komorida was born on July 10,1981.
#
# User: If I have more pieces at the time of stalemate, have I won?
# Almond: No.
# Stalemate is a drawn position. It doesn't matter who has captured more pieces or is in a winning position
#
# User: Given a reference text about Lollapalooza, where does it take place, who started it and what is it?
# Almond: Lollapalooze is an annual musical festival held in Grant Park in Chi

# %%
# convert to tokens
tokens = text.encode('utf-8')
tokens = list(map(int, tokens))
print(f"Length of tokens: {len(tokens)}")
print(f"Preview tokens:\n{tokens[:1000]}")
# Out:
# Length of tokens: 6711368
# Preview tokens:
# [85, 115, 101, 114, 58, 32, 87, 104, 101, 110, 32, 100, 105, 100, 32, 86, 105, 114, 103, 105, 110, 32, 65, 117, 115, 116, 114, 97, 108, 105, 97, 32, 115, 116, 97, 114, 116, 32, 111, 112, 101, 114, 97, 116, 105, 110, 103, 63, 10, 65, 108, 109, 111, 110, 100, 58, 32, 86, 105, 114, 103, 105, 110, 32, 65, 117, 115, 116, 114, 97, 108, 105, 97, 32, 99, 111, 109, 109, 101, 110, 99, 101, 100, 32, 115, 101, 114, 118, 105, 99, 101, 115, 32, 111, 110, 32, 51, 49, 32, 65, 117, 103, 117, 115, 116, 32, 50, 48, 48, 48, 32, 97, 115, 32, 86, 105, 114, 103, 105, 110, 32, 66, 108, 117, 101, 44, 32, 119, 105, 116, 104, 32, 116, 119, 111, 32, 97, 105, 114, 99, 114, 97, 102, 116, 32, 111, 110, 32, 97, 32, 115, 105, 110, 103, 108, 101, 32, 114, 111, 117, 116, 101, 46, 10, 10, 85, 115, 101, 114, 58, 32, 87, 104, 105, 99, 104, 32, 105, 115, 32, 97, 32, 115, 112, 101, 99, 105, 101, 115, 32, 111, 102, 32, 102, 105, 115, 104, 63, 32, 84, 111, 112, 101, 32, 111, 114, 32, 82, 111, 112, 101, 10, 65, 108, 109, 111, 110, 100, 58, 32, 84, 111, 112, 101, 10, 10, 85, 115, 101, 114, 58, 32, 87, 104, 121, 32, 99, 97, 110, 32, 99, 97, 109, 101, 108, 115, 32, 115, 117, 114, 118, 105, 118, 101, 32, 102, 111, 114, 32, 108, 111, 110, 103, 32, 119, 105, 116, 104, 111, 117, 116, 32, 119, 97, 116, 101, 114, 63, 10, 65, 108, 109, 111, 110, 100, 58, 32, 67, 97, 109, 101, 108, 115, 32, 117, 115, 101, 32, 116, 104, 101, 32, 102, 97, 116, 32, 105, 110, 32, 116, 104, 101, 105, 114, 32, 104, 117, 109, 112, 115, 32, 116, 111, 32, 107, 101, 101, 112, 32, 116, 104, 101, 109, 32, 102, 105, 108, 108, 101, 100, 32, 119, 105, 116, 104, 32, 101, 110, 101, 114, 103, 121, 32, 97, 110, 100, 32, 104, 121, 100, 114, 97, 116, 105, 111, 110, 32, 102, 111, 114, 32, 108, 111, 110, 103, 32, 112, 101, 114, 105, 111, 100, 115, 32, 111, 102, 32, 116, 105, 109, 101, 46, 10, 10, 85, 115, 101, 114, 58, 32, 65, 108, 105, 99, 101, 39, 115, 32, 112, 97, 114, 101, 110, 116, 115, 32, 104, 97, 118, 101, 32, 116, 104, 114, 101, 101, 32, 100, 97, 117, 103, 104, 116, 101, 114, 115, 58, 32, 65, 109, 121, 44, 32, 74, 101, 115, 115, 121, 44, 32, 97, 110, 100, 32, 119, 104, 97, 116, 226, 128, 153, 115, 32, 116, 104, 101, 32, 110, 97, 109, 101, 32, 111, 102, 32, 116, 104, 101, 32, 116, 104, 105, 114, 100, 32, 100, 97, 117, 103, 104, 116, 101, 114, 63, 10, 65, 108, 109, 111, 110, 100, 58, 32, 84, 104, 101, 32, 110, 97, 109, 101, 32, 111, 102, 32, 116, 104, 101, 32, 116, 104, 105, 114, 100, 32, 100, 97, 117, 103, 104, 116, 101, 114, 32, 105, 115, 32, 65, 108, 105, 99, 101, 10, 10, 85, 115, 101, 114, 58, 32, 87, 104, 101, 110, 32, 119, 97, 115, 32, 84, 111, 109, 111, 97, 107, 105, 32, 75, 111, 109, 111, 114, 105, 100, 97, 32, 98, 111, 114, 110, 63, 10, 65, 108, 109, 111, 110, 100, 58, 32, 84, 111, 109, 111, 97, 107, 105, 32, 75, 111, 109, 111, 114, 105, 100, 97, 32, 119, 97, 115, 32, 98, 111, 114, 110, 32, 111, 110, 32, 74, 117, 108, 121, 32, 49, 48, 44, 49, 57, 56, 49, 46, 10, 10, 85, 115, 101, 114, 58, 32, 73, 102, 32, 73, 32, 104, 97, 118, 101, 32, 109, 111, 114, 101, 32, 112, 105, 101, 99, 101, 115, 32, 97, 116, 32, 116, 104, 101, 32, 116, 105, 109, 101, 32, 111, 102, 32, 115, 116, 97, 108, 101, 109, 97, 116, 101, 44, 32, 104, 97, 118, 101, 32, 73, 32, 119, 111, 110, 63, 10, 65, 108, 109, 111, 110, 100, 58, 32, 78, 111, 46, 32, 10, 83, 116, 97, 108, 101, 109, 97, 116, 101, 32, 105, 115, 32, 97, 32, 100, 114, 97, 119, 110, 32, 112, 111, 115, 105, 116, 105, 111, 110, 46, 32, 73, 116, 32, 100, 111, 101, 115, 110, 39, 116, 32, 109, 97, 116, 116, 101, 114, 32, 119, 104, 111, 32, 104, 97, 115, 32, 99, 97, 112, 116, 117, 114, 101, 100, 32, 109, 111, 114, 101, 32, 112, 105, 101, 99, 101, 115, 32, 111, 114, 32, 105, 115, 32, 105, 110, 32, 97, 32, 119, 105, 110, 110, 105, 110, 103, 32, 112, 111, 115, 105, 116, 105, 111, 110, 10, 10, 85, 115, 101, 114, 58, 32, 71, 105, 118, 101, 110, 32, 97, 32, 114, 101, 102, 101, 114, 101, 110, 99, 101, 32, 116, 101, 120, 116, 32, 97, 98, 111, 117, 116, 32, 76, 111, 108, 108, 97, 112, 97, 1 ...

# %% [markdown]
# you can see, tokens on above need to known merges and vocab size

# %% [markdown]
# #### Tokenization BPE (Byte Pair Encoding)

# %%
def get_stats(ids):
    '''This function is defined to find the number of words in bigram form.'''
    counts = {}
    for pair in zip(ids, ids[1:]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge(ids, pair, idx):
    '''This function is defined to combine 2 frequently occurring words (bigram) into new tokens.'''
    newids = []
    i = 0
    while i < len(ids):
        if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
            newids.append(idx)
            i += 2
        else:
            newids.append(ids[i])
            i += 1
    return newids

# ------- train -----------
# We will get mapping word (vocab) and result of merges
vocab_size = 768 # size vocab 
num_merges = vocab_size - 256 # default byte 0-255
ids = list(tokens) # duplicate to save real tokens
merges = {}

for i in range(num_merges):
    stats = get_stats(ids)
    pair = max(stats, key=stats.get)
    idx = 256 + i
    print(f'merging {pair} into a new token {idx}')
    ids = merge(ids, pair, idx)
    merges[pair] = idx
# Out:
# merging (101, 32) into a new token 256
# merging (115, 32) into a new token 257
# merging (116, 104) into a new token 258
# merging (105, 110) into a new token 259
# merging (101, 114) into a new token 260
# merging (97, 110) into a new token 261
# merging (100, 32) into a new token 262
# merging (116, 32) into a new token 263
# merging (111, 110) into a new token 264
# merging (44, 32) into a new token 265
# merging (258, 256) into a new token 266
# merging (97, 114) into a new token 267
# merging (111, 114) into a new token 268
# merging (101, 110) into a new token 269
# merging (121, 32) into a new token 270
# merging (97, 108) into a new token 271
# merging (111, 32) into a new token 272
# merging (111, 117) into a new token 273
# merging (116, 105) into a new token 274
# merging (58, 32) into a new token 275
# merging (97, 32) into a new token 276
# merging (259, 103) into a new token 277
# merging (114, 101) into a new token 278
# merging (102, 32) into a new token 279
# merging (46, 32) into a new token 280
# merging (261, 262) into a new token 281
# merging (111, 279) into a new token 282
# merging (105, 257) into a new token 283
# merging (101, 262) into a new token 284
# merging (101, 115) into a new token 285
# merging (277, 32) into a new token 286
# merging (116, 272) into a new token 287
# merging (105, 99) into a new token 288
# merging (97, 116) into a new token 289
# merging (260, 32) into a new token 290
# merging (259, 32) into a new token 291
# merging (115, 116) into a new token 292
# merging (111, 109) into a new token 293
# merging (264, 32) into a new token 294
# merging (101, 257) into a new token 295
# merging (10, 10) into a new token 296
# merging (101, 108) into a new token 297
# merging (97, 263) into a new token 298
# merging (97, 99) into a new token 299
# merging (268, 32) into a new token 300
# merging (105, 116) into a new token 301
# merging (115, 260) into a new token 302
# merging (105, 108) into a new token 303
# merging (109, 264) into a new token 304
# merging (65, 108) into a new token 305
# merging (97, 115) into a new token 306
# merging (97, 257) into a new token 307
# merging (261, 32) into a new token 308
# merging (97, 109) into a new token 309
# merging (100, 275) into a new token 310
# merging (111, 119) into a new token 311
# merging (10, 305) into a new token 312
# merging (296, 85) into a new token 313
# merging (302, 275) into a new token 314
# merging (312, 304) into a new token 315
# merging (315, 310) into a new token 316
# merging (313, 314) into a new token 317
# merging (111, 108) into a new token 318
# merging (104, 32) into a new token 319
# merging (105, 115) into a new token 320
# merging (271, 32) into a new token 321
# merging (101, 99) into a new token 322
# merging (84, 104) into a new token 323
# merging (114, 111) into a new token 324
# merging (112, 108) into a new token 325
# merging (271, 108) into a new token 326
# merging (119, 104) into a new token 327
# merging (267, 256) into a new token 328
# merging (269, 32) into a new token 329
# merging (117, 115) into a new token 330
# merging (117, 114) into a new token 331
# merging (97, 274) into a new token 332
# merging (100, 105) into a new token 333
# merging (258, 32) into a new token 334
# merging (115, 105) into a new token 335
# merging (101, 116) into a new token 336
# merging (121, 273) into a new token 337
# merging (118, 256) into a new token 338
# merging (114, 105) into a new token 339
# merging (46, 317) into a new token 340
# merging (101, 109) into a new token 341
# merging (99, 104) into a new token 342
# merging (105, 114) into a new token 343
# merging (108, 105) into a new token 344
# merging (87, 104) into a new token 345
# merging (117, 108) into a new token 346
# merging (63, 316) into a new token 347
# merging (117, 110) into a new token 348
# merging (97, 103) into a new token 349
# merging (102, 300) into a new token 350
# merging (108, 101) into a new token 351
# merging (115, 265) into a new token 352
# merging (323, 256) into a new token 353
# merging (97, 98) into a new token 354
# merging (269, 116) into a new token 355
# merging (107, 32) into a new token 356
# merging (119, 105) into a new token 357
# merging (97, 100) into a new token 358
# merging (282, 266) into a new token 359
# merging (110, 32) into a new token 360
# merging (111, 115) into a new token 361
# merging (101, 265) into a new token 362
# merging (258, 298) into a new token 363
# merging (97, 112) into a new token 364
# merging (101, 120) into a new token 365
# merging (116, 114) into a new token 366
# merging (111, 112) into a new token 367
# merging (118, 260) into a new token 368
# merging (117, 109) into a new token 369
# merging (99, 293) into a new token 370
# merging (111, 111) into a new token 371
# merging (269, 263) into a new token 372
# merging (112, 324) into a new token 373
# merging (105, 103) into a new token 374
# merging (108, 32) into a new token 375
# merging (99, 264) into a new token 376
# merging (117, 99) into a new token 377
# merging (115, 104) into a new token 378
# merging (101, 100) into a new token 379
# merging (97, 121) into a new token 380
# merging (357, 334) into a new token 381
# merging (273, 110) into a new token 382
# merging (102, 114) into a new token 383
# merging (97, 107) into a new token 384
# merging (337, 32) into a new token 385
# merging (291, 266) into a new token 386
# merging (45, 32) into a new token 387
# merging (105, 263) into a new token 388
# merging (293, 32) into a new token 389
# merging (104, 97) into a new token 390
# merging (115, 112) into a new token 391
# merging (105, 100) into a new token 392
# merging (111, 99) into a new token 393
# merging (116, 260) into a new token 394
# merging (119, 307) into a new token 395
# merging (102, 268) into a new token 396
# merging (260, 256) into a new token 397
# merging (108, 256) into a new token 398
# merging (98, 256) into a new token 399
# merging (267, 32) into a new token 400
# merging (114, 32) into a new token 401
# merging (258, 101) into a new token 402
# merging (99, 256) into a new token 403
# merging (102, 102) into a new token 404
# merging (105, 109) into a new token 405
# merging (108, 270) into a new token 406
# merging (115, 101) into a new token 407
# merging (98, 270) into a new token 408
# merging (112, 32) into a new token 409
# merging (332, 264) into a new token 410
# merging (113, 117) into a new token 411
# merging (340, 345) into a new token 412
# merging (311, 32) into a new token 413
# merging (98, 101) into a new token 414
# merging (99, 308) into a new token 415
# merging (112, 260) into a new token 416
# merging (97, 270) into a new token 417
# merging (108, 262) into a new token 418
# merging (265, 281) into a new token 419
# merging (115, 280) into a new token 420
# merging (383, 389) into a new token 421
# merging (288, 319) into a new token 422
# merging (100, 101) into a new token 423
# merging (326, 32) into a new token 424
# merging (274, 264) into a new token 425
# merging (39, 257) into a new token 426
# merging (261, 100) into a new token 427
# merging (110, 101) into a new token 428
# merging (111, 116) into a new token 429
# merging (99, 108) into a new token 430
# merging (50, 48) into a new token 431
# merging (292, 114) into a new token 432
# merging (112, 267) into a new token 433
# merging (332, 294) into a new token 434
# merging (285, 263) into a new token 435
# merging (258, 290) into a new token 436
# merging (98, 117) into a new token 437
# merging (111, 263) into a new token 438
# merging (119, 268) into a new token 439
# merging (116, 257) into a new token 440
# merging (49, 57) into a new token 441
# merging (111, 118) into a new token 442
# merging (260, 257) into a new token 443
# merging (289, 256) into a new token 444
# merging (273, 263) into a new token 445
# merging (97, 259) into a new token 446
# merging (109, 261) into a new token 447
# merging (112, 101) into a new token 448
# merging (103, 114) into a new token 449
# merging (288, 32) into a new token 450
# merging (280, 32) into a new token 451
# merging (293, 256) into a new token 452
# merging (73, 32) into a new token 453
# merging (115, 272) into a new token 454
# merging (226, 128) into a new token 455
# merging (337, 401) into a new token 456
# merging (121, 265) into a new token 457
# merging (97, 118) into a new token 458
# merging (109, 256) into a new token 459
# merging (283, 276) into a new token 460
# merging (278, 115) into a new token 461
# merging (274, 99) into a new token 462
# merging (273, 418) into a new token 463
# merging (327, 422) into a new token 464
# merging (390, 338) into a new token 465
# merging (111, 100) into a new token 466
# merging (264, 256) into a new token 467
# merging (257, 281) into a new token 468
# merging (116, 290) into a new token 469
# merging (111, 103) into a new token 470
# merging (326, 270) into a new token 471
# merging (301, 270) into a new token 472
# merging (261, 103) into a new token 473
# merging (274, 294) into a new token 474
# merging (101, 263) into a new token 475
# merging (116, 101) into a new token 476
# merging (119, 101) into a new token 477
# merging (103, 104) into a new token 478
# merging (285, 265) into a new token 479
# merging (343, 32) into a new token 480
# merging (374, 104) into a new token 481
# merging (101, 118) into a new token 482
# merging (10, 387) into a new token 483
# merging (97, 265) into a new token 484
# merging (284, 287) into a new token 485
# merging (283, 266) into a new token 486
# merging (115, 117) into a new token 487
# merging (109, 101) into a new token 488
# merging (269, 100) into a new token 489
# merging (119, 32) into a new token 490
# merging (280, 73) into a new token 491
# merging (361, 263) into a new token 492
# merging (256, 282) into a new token 493
# merging (412, 298) into a new token 494
# merging (32, 281) into a new token 495
# merging (117, 116) into a new token 496
# merging (280, 353) into a new token 497
# merging (257, 282) into a new token 498
# merging (105, 118) into a new token 499
# merging (318, 108) into a new token 500
# merging (264, 103) into a new token 501
# merging (117, 100) into a new token 502
# merging (67, 104) into a new token 503
# merging (101, 267) into a new token 504
# merging (268, 256) into a new token 505
# merging (110, 438) into a new token 506
# merging (104, 307) into a new token 507
# merging (273, 114) into a new token 508
# merging (303, 375) into a new token 509
# merging (384, 256) into a new token 510
# merging (258, 283) into a new token 511
# merging (46, 296) into a new token 512
# merging (98, 108) into a new token 513
# merging (317, 345) into a new token 514
# merging (287, 266) into a new token 515
# merging (41, 32) into a new token 516
# merging (83, 116) into a new token 517
# merging (335, 100) into a new token 518
# merging (278, 99) into a new token 519
# merging (112, 104) into a new token 520
# merging (325, 256) into a new token 521
# merging (294, 266) into a new token 522
# merging (268, 116) into a new token 523
# merging (396, 109) into a new token 524
# merging (289, 284) into a new token 525
# merging (115, 263) into a new token 526
# merging (402, 480) into a new token 527
# merging (65, 32) into a new token 528
# merging (267, 100) into a new token 529
# merging (309, 256) into a new token 530
# merging (286, 266) into a new token 531
# merging (311, 360) into a new token 532
# merging (271, 454) into a new token 533
# merging (111, 98) into a new token 534
# merging (46, 10) into a new token 535
# merging (297, 32) into a new token 536
# merging (105, 295) into a new token 537
# merging (261, 99) into a new token 538
# merging (102, 101) into a new token 539
# merging (99, 278) into a new token 540
# merging (269, 99) into a new token 541
# merging (112, 111) into a new token 542
# merging (306, 115) into a new token 543
# merging (285, 116) into a new token 544
# merging (107, 256) into a new token 545
# merging (46, 316) into a new token 546
# merging (73, 110) into a new token 547
# merging (101, 112) into a new token 548
# merging (257, 287) into a new token 549
# merging (109, 492) into a new token 550
# merging (285, 256) into a new token 551
# merging (105, 122) into a new token 552
# merging (97, 291) into a new token 553
# merging (98, 111) into a new token 554
# merging (111, 436) into a new token 555
# merging (48, 32) into a new token 556
# merging (261, 263) into a new token 557
# merging (97, 292) into a new token 558
# merging (402, 270) into a new token 559
# merging (99, 111) into a new token 560
# merging (112, 114) into a new token 561
# merging (280, 323) into a new token 562
# merging (330, 256) into a new token 563
# merging (102, 108) into a new token 564
# merging (119, 509) into a new token 565
# merging (115, 452) into a new token 566
# merging (104, 101) into a new token 567
# merging (109, 260) into a new token 568
# merging (269, 403) into a new token 569
# merging (331, 256) into a new token 570
# merging (109, 505) into a new token 571
# merging (354, 445) into a new token 572
# merging (267, 103) into a new token 573
# merging (447, 270) into a new token 574
# merging (101, 103) into a new token 575
# merging (98, 114) into a new token 576
# merging (269, 274) into a new token 577
# merging (349, 256) into a new token 578
# merging (371, 262) into a new token 579
# merging (100, 377) into a new token 580
# merging (404, 260) into a new token 581
# merging (85, 110) into a new token 582
# merging (320, 263) into a new token 583
# merging (112, 278) into a new token 584
# merging (260, 265) into a new token 585
# merging (102, 343) into a new token 586
# merging (297, 108) into a new token 587
# merging (105, 292) into a new token 588
# merging (107, 110) into a new token 589
# merging (97, 102) into a new token 590
# merging (299, 319) into a new token 591
# merging (105, 338) into a new token 592
# merging (370, 112) into a new token 593
# merging (109, 267) into a new token 594
# merging (257, 328) into a new token 595
# merging (98, 306) into a new token 596
# merging (117, 278) into a new token 597
# merging (297, 375) into a new token 598
# merging (325, 380) into a new token 599
# merging (102, 259) into a new token 600
# merging (115, 99) into a new token 601
# merging (284, 408) into a new token 602
# merging (118, 392) into a new token 603
# merging (299, 104) into a new token 604
# merging (437, 263) into a new token 605
# merging (109, 32) into a new token 606
# merging (354, 398) into a new token 607
# merging (100, 272) into a new token 608
# merging (100, 114) into a new token 609
# merging (277, 265) into a new token 610
# merging (377, 319) into a new token 611
# merging (97, 262) into a new token 612
# merging (341, 32) into a new token 613
# merging (121, 112) into a new token 614
# merging (101, 280) into a new token 615
# merging (301, 257) into a new token 616
# merging (103, 278) into a new token 617
# merging (101, 270) into a new token 618
# merging (309, 32) into a new token 619
# merging (285, 115) into a new token 620
# merging (111, 102) into a new token 621
# merging (105, 274) into a new token 622
# merging (370, 109) into a new token 623
# merging (98, 322) into a new token 624
# merging (327, 329) into a new token 625
# merging (105, 32) into a new token 626
# merging (261, 116) into a new token 627
# merging (104, 283) into a new token 628
# merging (99, 267) into a new token 629
# merging (284, 291) into a new token 630
# merging (285, 257) into a new token 631
# merging (448, 111) into a new token 632
# merging (102, 346) into a new token 633
# merging (100, 111) into a new token 634
# merging (258, 260) into a new token 635
# merging (104, 256) into a new token 636
# merging (273, 257) into a new token 637
# merging (259, 256) into a new token 638
# merging (99, 382) into a new token 639
# merging (344, 545) into a new token 640
# merging (97, 303) into a new token 641
# merging (276, 108) into a new token 642
# merging (105, 264) into a new token 643
# merging (333, 581) into a new token 644
# merging (259, 430) into a new token 645
# merging (119, 289) into a new token 646
# merging (306, 263) into a new token 647
# merging (327, 298) into a new token 648
# merging (97, 119) into a new token 649
# merging (268, 100) into a new token 650
# merging (98, 336) into a new token 651
# merging (586, 526) into a new token 652
# merging (320, 104) into a new token 653
# merging (103, 319) into a new token 654
# merging (115, 256) into a new token 655
# merging (65, 110) into a new token 656
# merging (382, 262) into a new token 657
# merging (105, 102) into a new token 658
# merging (117, 256) into a new token 659
# merging (116, 119) into a new token 660
# merging (102, 500) into a new token 661
# merging (303, 108) into a new token 662
# merging (103, 269) into a new token 663
# merging (299, 116) into a new token 664
# merging (297, 270) into a new token 665
# merging (299, 107) into a new token 666
# merging (347, 353) into a new token 667
# merging (105, 321) into a new token 668
# merging (117, 409) into a new token 669
# merging (105, 112) into a new token 670
# merging (70, 114) into a new token 671
# merging (273, 654) into a new token 672
# merging (514, 298) into a new token 673
# merging (295, 282) into a new token 674
# merging (97, 117) into a new token 675
# merging (109, 259) into a new token 676
# merging (311, 286) into a new token 677
# merging (259, 394) into a new token 678
# merging (322, 116) into a new token 679
# merging (103, 111) into a new token 680
# merging (288, 321) into a new token 681
# merging (327, 272) into a new token 682
# merging (348, 100) into a new token 683
# merging (280, 83) into a new token 684
# merging (288, 107) into a new token 685
# merging (280, 72) into a new token 686
# merging (335, 264) into a new token 687
# merging (645, 502) into a new token 688
# merging (301, 256) into a new token 689
# merging (568, 288) into a new token 690
# merging (276, 115) into a new token 691
# merging (273, 401) into a new token 692
# merging (34, 32) into a new token 693
# merging (65, 690) into a new token 694
# merging (269, 103) into a new token 695
# merging (98, 290) into a new token 696
# merging (104, 297) into a new token 697
# merging (376, 116) into a new token 698
# merging (117, 112) into a new token 699
# merging (397, 328) into a new token 700
# merging (109, 303) into a new token 701
# merging (299, 356) into a new token 702
# merging (50, 32) into a new token 703
# merging (119, 463) into a new token 704
# merging (274, 459) into a new token 705
# merging (295, 281) into a new token 706
# merging (112, 367) into a new token 707
# merging (99, 319) into a new token 708
# merging (267, 105) into a new token 709
# merging (501, 32) into a new token 710
# merging (100, 320) into a new token 711
# merging (267, 262) into a new token 712
# merging (32, 32) into a new token 713
# merging (632, 521) into a new token 714
# merging (265, 266) into a new token 715
# merging (478, 263) into a new token 716
# merging (115, 121) into a new token 717
# merging (455, 153) into a new token 718
# merging (101, 368) into a new token 719
# merging (261, 270) into a new token 720
# merging (100, 289) into a new token 721
# merging (116, 614) into a new token 722
# merging (303, 256) into a new token 723
# merging (107, 286) into a new token 724
# merging (289, 116) into a new token 725
# merging (382, 100) into a new token 726
# merging (288, 256) into a new token 727
# merging (266, 98) into a new token 728
# merging (267, 270) into a new token 729
# merging (274, 118) into a new token 730
# merging (100, 285) into a new token 731
# merging (299, 256) into a new token 732
# merging (361, 256) into a new token 733
# merging (257, 291) into a new token 734
# merging (259, 116) into a new token 735
# merging (258, 551) into a new token 736
# merging (103, 108) into a new token 737
# merging (391, 322) into a new token 738
# merging (109, 372) into a new token 739
# merging (276, 98) into a new token 740
# merging (274, 109) into a new token 741
# merging (301, 284) into a new token 742
# merging (119, 397) into a new token 743
# merging (109, 355) into a new token 744
# merging (109, 330) into a new token 745
# merging (258, 308) into a new token 746
# merging (284, 266) into a new token 747
# merging (707, 346) into a new token 748
# merging (105, 279) into a new token 749
# merging (53, 32) into a new token 750
# merging (101, 591) into a new token 751
# merging (257, 363) into a new token 752
# merging (371, 100) into a new token 753
# merging (442, 290) into a new token 754
# merging (118, 105) into a new token 755
# merging (78, 101) into a new token 756
# merging (112, 461) into a new token 757
# merging (421, 266) into a new token 758
# merging (112, 523) into a new token 759
# merging (491, 263) into a new token 760
# merging (273, 116) into a new token 761
# merging (267, 116) into a new token 762
# merging (115, 611) into a new token 763
# merging (116, 339) into a new token 764
# merging (259, 100) into a new token 765
# merging (102, 270) into a new token 766
# merging (110, 309) into a new token 767

# %%
# Get vocab dictionary
vocab = {idx: bytes([idx]) for idx in range(256)}
# Merges tree into vocab
for (p0, p1), idx in merges.items():
    vocab[idx] = vocab[p0] + vocab[p1]
print(f"Vocab dictionary succesfully created.")
print(f"Length of vocab: {len(vocab)}")
# Out:
# Vocab dictionary succesfully created.
# Length of vocab: 768

# %%
def encode(text):
    '''Encode text into list of integers'''
    ids = list(text.encode('utf-8'))
    while len(ids) >= 2:
        stats = get_stats(ids)
        pair = min(stats, key=lambda p: merges.get(p, float('inf')))
        if pair not in merges:
            break
        ids = merge(ids, pair, merges[pair])
    return ids

def decode(ids):
    '''Decode list of integers into string'''
    tokens = b''.join([vocab[i] for i in ids])
    text = tokens.decode('utf-8', errors='replace')
    return text

# %%
# Validate check
raw = 'Almond What'
raw2 = decode(encode(raw))
print(raw == raw2)
# Out:
# True
